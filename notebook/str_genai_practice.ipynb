# %% [markdown]
# * 1.  Install ollama
# * 2. ollama run gemma3:1b
# * 3 uv add langchain-ollama
# * 4 uv add ollama

# %%
from langchain_ollama import ChatOllama

# %%
# !ollama list
# Out:
# NAME                       ID              SIZE      MODIFIED
# gemma3:1b                  8648f39daa8f    815 MB    2 days ago
# qwen3:0.6b                 7df6b6e09427    522 MB    2 days ago
# deepseek-r1:1.5b           e0979632db5a    1.1 GB    4 weeks ago
# qwen3:4b                   2bfd38a7daaf    2.6 GB    4 weeks ago
# qwen3:8b                   500a1f067a9f    5.2 GB    4 weeks ago
# gemma3n:e2b                719372f8c7de    5.6 GB    4 weeks ago
# gemma3n:e4b                15cb39fd9394    7.5 GB    4 weeks ago
# qwen3:1.7b                 458ce03a2187    1.4 GB    3 months ago
# phi4-mini:latest           78fad5d182a7    2.5 GB    3 months ago
# nomic-embed-text:latest    0a109f422b47    274 MB    3 months ago

# %%
llm = ChatOllama(
    model="gemma3:1b")

# %%
response = llm.invoke("what si newton 3rd law")
response
# Out:
# AIMessage(content='Okay, let\'s break down the Newton\'s Third Law of Motion. It’s a cornerstone of physics and surprisingly simple in its core, but incredibly important.\n\n**Newton\'s Third Law of Motion: "For every action, there is an equal and opposite reaction."**\n\nHere’s a breakdown of what it means and why it’s significant:\n\n**1. The Core Concept:**\n\n* **Action:** This is *what* an object does.  It’s the force being applied.\n* **Reaction:** This is *what* the object does in response. It’s an equal and opposite force that comes back to the object.\n\n**2.  Key Points:**\n\n* **Equal in Magnitude:** The forces acting are of the *same* strength.  If you push on a wall, the wall pushes back with the same force.\n* **Opposite in Direction:** The forces act in opposite directions. They don\'t cancel each other out; they always act in opposite ways.\n\n**3.  Examples to Illustrate:**\n\n* **Walking:** When you walk, you push backward on the ground with your feet.  The ground then pushes forward on your feet, propelling you forward.\n* **Rocket Launch:** A rocket expels hot gases downward.  These gases exert an equal and opposite force upwards on the rocket, causing it to accelerate upwards.\n* **A bowling ball on a stretched rubber surface:**  When the bowling ball is dropped, it creates a force that pushes the rubber surface outward. The rubber surface then exerts an equal and opposite force back on the bowling ball, causing it to roll.\n* **Birds flying:**  A bird\'s wings create an upward force that counteracts gravity.\n\n**4.  Important Implications & Why it Matters:**\n\n* **Balance:** This law is fundamental to understanding balance.  If you were to remove one of the forces in a balanced system, the system would inevitably start to fall or move.\n* **Stability:**  It helps explain how systems are stable.  Forces are always working against each other, contributing to a system\'s resistance to change.\n* **Physics in Action:**  It’s a basic principle behind many physical phenomena – from simple movements to complex engineering applications.\n\n\n**5.  Sometimes it\'s a bit more complex than it seems:**\n\n* **Net Force:** Newton\'s Third Law also applies when you consider the *net* force acting on an object.  The net force is the vector sum of all the forces acting on an object.  It’s the overall force that determines the object\'s acceleration.\n\n\n**In short, Newton\'s Third Law is a cornerstone of physics because it explains how forces always have a corresponding reciprocal effect.**\n\n---\n\n**Resources for Further Learning:**\n\n* **Wikipedia - Newton\'s Third Law:** [https://en.wikipedia.org/wiki/Newton%27s_third_law](https://en.wikipedia.org/wiki/Newton%27s_third_law)\n* **Crash Course Physics - Newton\'s Third Law:** [https://www.youtube.com/watch?v=jP4K1VqQ1Gg](https://www.youtube.com/watch?v=jP4K1VqQ1Gg)\n\n\nDo you have any specific questions about Newton’s Third Law that you’d like me to answer? For example, are you interested in:\n\n*   A deeper explanation of the mathematics involved?\n*   Its application to a particular scenario?', additional_kwargs={}, response_metadata={'model': 'gemma3:1b', 'created_at': '2025-08-14T02:58:56.237627689Z', 'done': True, 'done_reason': 'stop', 'total_duration': 46857295849, 'load_duration': 684191891, 'prompt_eval_count': 17, 'prompt_eval_duration': 137166722, 'eval_count': 748, 'eval_duration': 46035138952, 'model_name': 'gemma3:1b'}, id='run--829983c8-6aab-43c1-91a6-96fb28f4b242-0', usage_metadata={'input_tokens': 17, 'output_tokens': 748, 'total_tokens': 765})

# %%
print(response.content)
# Out:
# Okay, let's break down the Newton's Third Law of Motion. It’s a cornerstone of physics and surprisingly simple in its core, but incredibly important.
#
# **Newton's Third Law of Motion: "For every action, there is an equal and opposite reaction."**
#
# Here’s a breakdown of what it means and why it’s significant:
#
# **1. The Core Concept:**
#
# * **Action:** This is *what* an object does.  It’s the force being applied.
# * **Reaction:** This is *what* the object does in response. It’s an equal and opposite force that comes back to the object.
#
# **2.  Key Points:**
#
# * **Equal in Magnitude:** The forces acting are of the *same* strength.  If you push on a wall, the wall pushes back with the same force.
# * **Opposite in Direction:** The forces act in opposite directions. They don't cancel each other out; they always act in opposite ways.
#
# **3.  Examples to Illustrate:**
#
# * **Walking:** When you walk, you push backward on the ground with your feet.  The ground then pushes forward on your feet, propelling you forward.
# * **Rocket Launch:** A rocket expels hot gases downward.  These gases exert an equal and opposite force upwards on the rocket, causing it to accelerate upwards.
# * **A bowling ball on a stretched rubber surface:**  When the bowling ball is dropped, it creates a force that pushes the rubber surface outward. The rubber surface then exerts an equal and opposite force back on the bowling ball, causing it to roll.
# * **Birds flying:**  A bird's wings create an upward force that counteracts gravity.
#
# **4.  Important Implications & Why it Matters:**
#
# * **Balance:** This law is fundamental to understanding balance.  If you were to remove one of the forces in a balanced system, the system would inevitably start to fall or move.
# * **Stability:**  It helps explain how systems are stable.  Forces are always working against each other, contributing to a system's resistance to change.
# * **Physics in Action:**  It’s a basic principle behind many physical phenomena – from simple movements to complex engineering applications.
#
#
# **5.  Sometimes it's a bit more complex than it seems:**
#
# * **Net Force:** Newton's Third Law also applies when you consider the *net* force acting on an object.  The net force is the vector sum of all the forces acting on an object.  It’s the overall force that determines the object's acceleration.
#
#
# **In short, Newton's Third Law is a cornerstone of physics because it explains how forces always have a corresponding reciprocal effect.**
#
# ---
#
# **Resources for Further Learning:**
#
# * **Wikipedia - Newton's Third Law:** [https://en.wikipedia.org/wiki/Newton%27s_third_law](https://en.wikipedia.org/wiki/Newton%27s_third_law)
# * **Crash Course Physics - Newton's Third Law:** [https://www.youtube.com/watch?v=jP4K1VqQ1Gg](https://www.youtube.com/watch?v=jP4K1VqQ1Gg)
#
#
# Do you have any specific questions about Newton’s Third Law that you’d like me to answer? For example, are you interested in:
#
# *   A deeper explanation of the mathematics involved?
# *   Its application to a particular scenario?

# %%
topic=input("Topic in which you want to know")
level=input("what is your level of understanding('Beginner,Intermediate or Advanced)")
role=input("For what application or role you are looking for")

# %%
prompt = f"I want to know about {topic} and i am {level} for {role} role"
prompt
# Out:
# 'I want to know about streamlit and i am beginner for genai role'

# %%
llm2 = ChatOllama(
    model="gemma3n:e2b")

# %%
response= llm.invoke(prompt)
print(response.content)
# Out:
# Okay, let's dive into Streamlit! It's a fantastic tool for building interactive web applications with minimal code. As a beginner, understanding Streamlit will be a big help. Here’s a breakdown of what it is, why it's useful, and how to get started, broken down into manageable chunks:
#
# **1. What is Streamlit?**
#
# * **Low-Code/No-Code Data Science Platform:** Streamlit is designed specifically for creating data-driven web applications. It lets you build interactive apps without needing to be a Python expert.
# * **Focus on Data Visualization & Exploration:** It excels at visualizing data, exploring datasets, and quickly creating dashboards.
# * **Python-First:**  It's built around Python, so you can leverage your existing Python knowledge.
#
# **2. Why Use Streamlit?**
#
# * **Rapid Prototyping:**  Streamlit lets you get a working prototype really quickly – often in a few hours.
# * **Easy to Learn:** The syntax is quite approachable, especially for those familiar with Python.
# * **Community-Driven:** A large and active community provides plenty of resources, tutorials, and support.
# * **Built-in Components:** Streamlit provides pre-built components like:
#     * **DataFrames:** For handling tabular data.
#     * **Buttons & Input Fields:**  For user interaction.
#     * **Charts & Graphs:**  To visualize your data.
#     * **Theming:**  To customize the look and feel of your app.
# * **Shareable:** You can easily share your apps with others via a link.
#
# **3. Getting Started with Streamlit**
#
# Let’s create a simple "Hello, World!" app:
#
# 1. **Install Streamlit:** Open your terminal or command prompt and run:
#    ```bash
#    pip install streamlit
#    ```
#
# 2. **Create Your First App:**  Create a new file (e.g., `my_app.py`) with the following content:
#
#    ```python
#    import streamlit as st
#
#    st.title("My First Streamlit App")
#
#    st.write("Hello, world!")
#
#    st.write("This is a simple app.")
#    ```
#
# 3. **Run Your App:**  In your terminal, navigate to the directory where you saved `my_app.py` and run:
#    ```bash
#    streamlit run my_app.py
#    ```
#
#    This will open a new tab in your web browser, displaying your app.  It will look something like this:
#
#    [You'll see a simple web page with "Hello, world!" in the title and a simple greeting.]
#
# **4. Key Concepts & Basic Workflow**
#
# * **`st.title()`:**  Displays a title on the screen.
# * **`st.write()`:** Displays text or data.
# * **`st.dataframe()`:** Displays a DataFrame (table).
# * **`st.button()`:** Creates a button that triggers an action.
# * **`st.text()`:** Displays text.
# * **`st.markdown()`:**  Embeds Markdown to create headings, lists, etc.
#
# **5.  Example:  A Simple Streamlit App That Shows a DataFrame**
#
# Here's a slightly more complex example that shows how to display a DataFrame:
#
# ```python
# import streamlit as st
# import pandas as pd
#
# st.title("Simple DataFrame App")
#
# data = pd.DataFrame({'Name': ['Alice', 'Bob', 'Charlie'],
#                     'Age': [25, 30, 22],
#                     'City': ['New York', 'London', 'Paris']})
#
# st.write("Data:")
# st.dataframe(data)
#
# st.write("The DataFrame is:")
# st.write(data)
#
# st.write("Button to show age of the most popular person:")
# #  This button will trigger a function that shows the most popular person.
# #  For example, you could use a function to find the maximum age
# def find_most_popular():
#     top_age = data['Age'].max()
#     return top_age
#
# st.button("Find Most Popular")
#
# ```
#
# **Explanation:**
#
# * We import `streamlit` and `pandas`.
# * We create a Pandas DataFrame (which is a table).
# * `st.dataframe()` displays the DataFrame in a table format.
# * `st.write()` displays the DataFrame.
# * The `st.button()` example adds a button that, when clicked, will run the `find_most_popular()` function.
#
# **6. Resources for Learning More**
#
# * **Streamlit Official Documentation:** [https://docs.streamlit.io/](https://docs.streamlit.io/) – The best place to start.
# * **Streamlit Tutorials:** [https://streamlit.io/tutorials](https://streamlit.io/tutorials) – They have interactive tutorials for various tasks.
# * **Streamlit Community:** [https://community.streamlit.io/](https://community.streamlit.io/) – For questions and help.
# * **Streamlit Blog:** [https://streamlit.io/blog](https://streamlit.io/blog) – Articles and insights on the platform.
#
# **7.  Next Steps –  If You Want to Build Something Bigger**
#
# Once you're comfortable with the basics, you can start exploring these:
#
# * **Data Cleaning:**  Dealing with missing data or inconsistencies in your data.
# * **Data Transformation:**  Converting data into a usable format.
# * **Interactive Widgets:** Creating buttons, sliders, etc., to make your app more engaging.
# * **Advanced Data Visualization:**  Using libraries like Matplotlib, Seaborn, or Plotly.
# * **User Input:**  Getting data from the user through forms.
#
# **To help me give you even more tailored guidance, could you tell me:**
#
# *   **What are you hoping to *do* with Streamlit?** (e.g., visualize data, build a simple dashboard, create a data exploration tool?)
# *   **What's your current level of Python experience?** (e.g., have you used any Python libraries before?)

# %%
response= llm2.invoke(prompt)
print(response.content)
# Out:
# Okay, let's break down Streamlit and how it's relevant for a Generative AI (GenAI) role.  I'll cover what Streamlit is, why it's valuable for GenAI, how to get started, and some key considerations for a beginner.
#
# **What is Streamlit?**
#
# Streamlit is an **open-source Python library** that makes it incredibly easy to build and share data apps.  Think of it as a tool that simplifies the process of creating interactive web applications with minimal coding.  It's designed for data scientists, analysts, and anyone who wants to quickly prototype and deploy tools for data exploration and visualization.
#
# **Key Features of Streamlit:**
#
# *   **Simple API:**  Streamlit's API is very intuitive. You write Python code, and Streamlit handles the front-end (HTML, CSS, JavaScript) for you.
# *   **Automatic UI Updates:**  Changes to your code are automatically reflected in the user interface.  This is a huge time-saver.
# *   **Built-in Components:**  Streamlit provides a rich set of pre-built UI components (e.g., text inputs, sliders, buttons, charts, tables) that you can easily combine.
# *   **Easy Deployment:**  Streamlit apps can be deployed to Streamlit Cloud (a hosted platform) or to other cloud providers (like AWS, Azure, or Google Cloud) with minimal setup.
# *   **Extensible:**  You can easily integrate with other Python libraries (like Pandas, NumPy, Scikit-learn, TensorFlow, PyTorch) to build complex data apps.
# *   **Community:**  A large and active community provides support, tutorials, and pre-built components.
#
# **Why is Streamlit Valuable for a Generative AI Role?**
#
# Generative AI is rapidly becoming a core part of many applications.  Here's how Streamlit fits in:
#
# *   **Prototyping and Experimentation:**  GenAI often involves experimentation with different models, prompts, and parameters. Streamlit allows you to quickly build and test these prototypes without writing extensive web infrastructure.
# *   **Demoing and Sharing:**  You can easily create a user-friendly interface to showcase your GenAI models and demonstrate their capabilities.  This is crucial for communicating your work to stakeholders.
# *   **Interactive Exploration:**  Streamlit enables users to interact with your GenAI models in real-time.  For example, you could build an app where users can input text prompts and see the generated text.
# *   **Model Evaluation and Analysis:**  You can use Streamlit to build tools for evaluating the performance of GenAI models.  This might involve displaying metrics, visualizing results, or allowing users to compare different models.
# *   **User-Friendly Interfaces:**  GenAI models can be complex. Streamlit helps create intuitive interfaces that make them accessible to non-technical users.
# *   **Rapid Iteration:**  The rapid development cycle of GenAI means you need to iterate quickly. Streamlit's ease of use makes this possible.
#
# **Getting Started with Streamlit (Beginner-Friendly)**
#
# 1.  **Installation:**
#     ```bash
#     pip install streamlit
#     ```
#
# 2.  **Basic App:**
#     ```python
#     import streamlit as st
#
#     st.title("My First Streamlit App")
#
#     st.write("This is a simple Streamlit app.")
#
#     st.write("You can add more content here.")
#
#     st.slider("Select a value", 0, 100, 50)  # Example slider
#     ```
#     Save this as `my_streamlit_app.py` and run it with:
#     ```bash
#     streamlit run my_streamlit_app.py
#     ```
#     This will open the app in your web browser.
#
# 3.  **Adding Data:**
#     ```python
#     import streamlit as st
#     import pandas as pd
#
#     st.title("Data App with Pandas")
#
#     # Load a CSV file
#     df = pd.read_csv("data.csv")  # Replace with your CSV file
#
#     st.dataframe(df)  # Display the DataFrame
#
#     st.line_chart(df['column_name']) # Display a line chart
#     ```
#     You'll need a `data.csv` file to test this.
#
# 4.  **Using Components:**
#     Streamlit has many components.  Here are a few examples:
#
#     *   `st.text_input`:  For text input fields.
#     *   `st.selectbox`:  For dropdown menus.
#     *   `st.button`:  For buttons.
#     *   `st.file_uploader`:  For uploading files.
#     *   `st.image`:  For displaying images.
#     *   `st.video`: For displaying videos.
#     *   `st.audio`: For displaying audio.
#     *   `st.checkbox`: For checkboxes.
#     *   `st.radio`: For radio buttons.
#
# **Example:  A Simple Text Generation App (Illustrating GenAI Use)**
#
# ```python
# import streamlit as st
# import openai
#
# # Set your OpenAI API key (replace with your actual key)
# openai.api_key = "YOUR_OPENAI_API_KEY"
#
# def generate_text(prompt):
#     response = openai.Completion.create(
#         engine="text-davinci-003",  # Or another suitable engine
#         prompt=prompt,
#         max_tokens=150,
#         n=1,
#         stop=None,
#         temperature=0.7,
#     )
#     return response.choices[0].text.strip()
#
# st.title("Text Generation App")
#
# user_prompt = st.text_input("Enter your prompt:", "Write a short story about a cat.")
#
# if st.button("Generate"):
#     if user_prompt:
#         generated_text = generate_text(user_prompt)
#         st.write("Generated Text:")
#         st.write(generated_text)
#     else:
#         st.warning("Please enter a prompt.")
# ```
#
# **Key Considerations for a GenAI Role (and Streamlit)**
#
# *   **API Keys:**  Protect your OpenAI API key!  Don't commit it directly to your code repository.  Use environment variables.
# *   **Error Handling:**  GenAI models can be unpredictable.  Implement error handling to gracefully handle potential issues (e.g., API errors, invalid prompts).
# *   **Prompt Engineering:**  The quality of the generated text depends heavily on the prompt.  Experiment with different prompts to get the best results.
# *   **Model Selection:**  Choose the right GenAI model for your task.  Consider factors like model size, cost, and capabilities.
# *   **Rate Limiting:**  Be aware of API rate limits and implement strategies to avoid exceeding them.
# *   **Security:**  If your app handles sensitive data, implement appropriate security measures.
# *   **User Experience (UX):**  Design a user-friendly interface that is easy to use and understand.
# *   **Scalability:**  Consider how your app will scale as the number of users grows.
# *   **Deployment:**  Choose a deployment platform that meets your needs (Streamlit Cloud, AWS, Azure, Google Cloud).
#
# **Resources for Learning Streamlit**
#
# *   **Official Streamlit Documentation:** [https://docs.streamlit.io/](https://docs.streamlit.io/)  (The best place to start!)
# *   **Streamlit Tutorials:** [https://streamlit.io/tutorials](https://streamlit.io/tutorials)
# *   **Streamlit Examples:** [https://streamlit.io/gallery](https://streamlit.io/gallery)
# *   **YouTube:** Search for "Streamlit tutorial" on YouTube.  There are many excellent videos.
# *   **Online Courses:**  Platforms like Coursera, Udemy, and DataCamp offer Streamlit courses.
#
# **To help me tailor my advice further, tell me:**
#
# *   **What specific GenAI tasks are you interested in?** (e.g., text generation, image generation, code generation, summarization, etc.)
# *   **What's your current Python experience like?** (e.g., beginner, intermediate, advanced)
# *   **Do you have any experience with APIs or cloud platforms?**
# *   **What kind of GenAI models are you most interested in using?** (e.g., OpenAI, Hugging Face, etc.)
#
#
#
# I hope this comprehensive overview is helpful!  Let me know if you have any more questions.  I'm happy to provide more specific guidance as you progress.  Good luck with your GenAI journey!
